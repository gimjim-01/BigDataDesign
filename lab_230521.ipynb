# %%
import pandas as pd
import numpy as np
# from yahoo_fin import options
import yfinance as yf
from datetime import datetime, timedelta
from datetime import date
from dateutil.parser import parse # 데이트 형식 자동변환
from copy import copy
# import openpyxl
# from openpyxl.utils.dataframe import dataframe_to_rows
from math import ceil
from more_itertools import locate
import math
import matplotlib.pyplot as plt # 그래프
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
# import FinanceDataReader as fdr
from tqdm import tqdm
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import openpyxl
from openpyxl.utils.dataframe import dataframe_to_rows
import random
from dateutil.relativedelta import relativedelta
from scipy.spatial import distance

# %%
def inequal_neg_mae(y_true, y_pred):
    gamma = 0.95
    sign_y_true = np.sign(y_true)
    loss =  sign_y_true * np.where(
        sign_y_true * (y_pred - y_true/2) >0, 
        (1 - gamma) * sign_y_true * np.abs(y_pred - y_true),
        - y_pred + (1 - gamma/2) * y_true 
        ) 
    # capped_loss = np.where(loss > 0.05, 0.05, loss)
    return 1 * loss

# %%
def show_score(func):
    l_pred_val = np.linspace(-0.2, 0.2, 1000)
    l_high_val = -0.1 * np.ones(1000)
    l_str_val = - 0.05 * np.ones(1000)
    l_med_val =  0.1 * np.ones(1000)
    l_weak_val = 0.05 * np.ones(1000)
    l_val = [l_high_val, l_str_val, l_med_val, l_weak_val]
    l_cols = ['red', 'darkorange', 'limegreen', 'lightseagreen']
    l_names= ['true val = ' +str(i[0]) for i in l_val]

    fig = plt.subplots(figsize=(4.5,4))
    # ax.axis('off')
    plt.axvline(x=0, color='k', linewidth=1)
    plt.axhline(y=0, color='k', linewidth=1)
    plt.xlim(-0.15, 0.15)
    plt.ylim(-0.15, 0.15)
    for true_type_, col_, name_ in zip(l_val, l_cols, l_names):
        plt.plot(l_pred_val, func(true_type_, l_pred_val), color = col_, label=name_)
        plt.xlabel('predict', fontsize=20)
        plt.ylabel(func.__name__, fontsize=20)
    #     ax.plot(l_pred_val, inequal_neg_mae(-true_type_, l_pred_val), color = col_)
    plt.legend()
    plt.show()
    return

# %% [markdown]
# ##### functions

# %%
# 주가, 거래량 데이터 받는 함수
def get_fin_data(ticker, period):
    # yahoo finance에서 데이터 불러오기
    df = pd.DataFrame(yf.download(tickers=ticker, period=period)[['Adj Close','Volume']])
    df.rename(columns = {'Adj Close':'price'},inplace=True)
    
    return df

# %%
# 과거 대비 수익률 데이터 & 미래 수익률 데이터
def cal_return(df, window_sizes, future):
    df_return =copy(df)
    train_col = [] # train data 들어갈 것
    test_col = [] # 실제 비교할 data에 들어갈 것
    
    # window 사이즈만큼 이동한 주가 데이터
    for window in window_sizes:
        df_return[f'p_b{window}'] = df['price'].shift(window)
    
    # 과거 대비 로그 평균 수익률 데이터 
    for window in window_sizes:
        df_return[f'return_b{window}'] = (np.log(df['price']) - np.log(df_return[f'p_b{window}'])) / window  
        train_col.append(f'return_b{window}')
        
    # 미래만큼 이동한 데이터
    for after in future:
        df_return[f'p_a{after}'] = df['price'].shift(-after)
        
    # 미래 일반(로그x) 수익률
    for after in future:
        df_return[f'return_a{after}'] = (df_return[f'p_a{after}']) / (df_return['price']) -1
        test_col.append(f'return_a{after}')
    
    train_df = df_return[train_col]
    test_df = df_return[test_col]
    
    return train_df, test_df

# %%
# 거래량 z-score 구하기
# (data - mean(data, axis=0)) / std(data, axis=0)
def vol_zscore(df, vol_len, scale):
    vol_df = copy(df)
    vol_col = []
    for window in scale:
        vol_df[f'vol_mean{window}'] = df['Volume'].rolling(window).mean()
        vol_df[f'vol_std{window}'] = df['Volume'].rolling(window).std()
        vol_df[f'vol_z{window}'] = (df['Volume'].rolling(vol_len).median() - vol_df[f'vol_mean{window}']) / vol_df[f'vol_std{window}']
        vol_col.append(f'vol_z{window}')
    
    vol_z_df = vol_df[vol_col]
    
    return vol_z_df

# %%
def eucli_sort_print(df, train_df, test_df, sort_num):
    for i in random_lst:
        # 마지막 행 날짜 추출
        globals()[f"last_date{i}"] = df.dropna().tail(end).index[i]
        # 마지막 행 데이터 추출
        globals()[f"last_row{i}"] = train_df.loc[eval(f"last_date{i}")]
        # 가장 마지막 행과 다른 행들 간의 유클리디안 디스턴스 계산
        globals()[f"euclidean_distances{i}"] = train_df.apply(lambda row: distance.euclidean(row, eval(f"last_row{i}")), axis=1)  
        globals()[f"eucli{i}"] = eval(f"euclidean_distances{i}")
        # sorting 하기
        globals()[f"eucli_sort{i}"] = eval(f"eucli{i}.sort_values()")
        # sort_num 만큼 sorting 하기
        globals()[f"eucli_sort_num{i}"] = eval(f"eucli_sort{i}.head(sort_num)")

# %% [markdown]
# #### T0 시점에서, 성과와 거래량을 어떻게 쓰기좋은 데이터로 변환하는가?

# %% [markdown]
# ##### price

# %% [markdown]
# 1) price: log(PXt0/PXt-20)/20, log(PXt0/PXt-40)/40, log(PXt0/PXt-60)/60 for price,
# 2) volume: mean(Volt0-Volt-20), mean(Volt0-volT-40), mean(Volt0-Volt-60) for volume

# %%
ticker = "^IXIC"
period = "max" # period: max, 1y, 5y etc.

nasdaq_df = get_fin_data(ticker, period)
nasdaq_df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    price      Volume
# Date
# 1971-02-05    100.000000           0
# 1971-02-08    100.839996           0
# 1971-02-09    100.760002           0
# 1971-02-10    100.690002           0
# 1971-02-11    101.449997           0
# ...                  ...         ...
# 2023-05-15  12365.209961  3979290000
# 2023-05-16  12343.049805  4067510000
# 2023-05-17  12500.570312  4501820000
# 2023-05-18  12688.839844  4532890000
# 2023-05-19  12711.992188   357870770
#
# [12820 rows x 2 columns]

# %%
# parameters
today = nasdaq.index[-1]#.date()
year = today - relativedelta(years=20)
# year20 = today - timedelta(days=5000)
# nasdaq = nasdaq.loc[nasdaq.index >= '2000-01-01']
window_sizes = [20, 40, 60, 80, 100]
future = [10, 20, 30, 40] # future 이후 수익률
sort_num = 30 # 유클리디안 sorting 할 길이

# %%
# window size 과거 대비 수익률, future 만큼 미래 수익률
train_df, test_df = cal_return(nasdaq_df, window_sizes, future)

display(train_df)
test_df
# Out:
#             return_b20  return_b40  return_b60  return_b80  return_b100
# Date
# 1971-02-05         NaN         NaN         NaN         NaN          NaN
# 1971-02-08         NaN         NaN         NaN         NaN          NaN
# 1971-02-09         NaN         NaN         NaN         NaN          NaN
# 1971-02-10         NaN         NaN         NaN         NaN          NaN
# 1971-02-11         NaN         NaN         NaN         NaN          NaN
# ...                ...         ...         ...         ...          ...
# 2023-05-15    0.000846    0.001531    0.000701    0.001631     0.001591
# 2023-05-16    0.000774    0.001390    0.000768    0.001281     0.001572
# 2023-05-17    0.001393    0.001315    0.001402    0.001191     0.001547
# 2023-05-18    0.002543    0.002093    0.001629    0.001411     0.001916
# 2023-05-19    0.002581    0.001888    0.001539    0.001457     0.001914
#
# [12820 rows x 5 columns]
#             return_a10  return_a20  return_a30  return_a40
# Date
# 1971-02-05   -0.003200    0.042300    0.053700    0.071700
# 1971-02-08   -0.011107    0.035403    0.042344    0.066640
# 1971-02-09   -0.001191    0.033545    0.039103    0.072449
# 1971-02-10    0.005363    0.035455    0.038832    0.076373
# 1971-02-11   -0.001084    0.030064    0.035683    0.073140
# ...                ...         ...         ...         ...
# 2023-05-15         NaN         NaN         NaN         NaN
# 2023-05-16         NaN         NaN         NaN         NaN
# 2023-05-17         NaN         NaN         NaN         NaN
# 2023-05-18         NaN         NaN         NaN         NaN
# 2023-05-19         NaN         NaN         NaN         NaN
#
# [12820 rows x 4 columns]

# %% [markdown]
# ##### volume

# %%
scale = [100, 200]
vol_len = 5
# scale 이동평균 대비 거래량 z-score 구하기
nasdaq_vol_df = vol_zscore(nasdaq_df, vol_len, scale)
nasdaq_vol_df
# Out:
#             vol_z100  vol_z200
# Date
# 1971-02-05       NaN       NaN
# 1971-02-08       NaN       NaN
# 1971-02-09       NaN       NaN
# 1971-02-10       NaN       NaN
# 1971-02-11       NaN       NaN
# ...              ...       ...
# 2023-05-15 -1.541453 -1.326617
# 2023-05-16 -1.389622 -1.191260
# 2023-05-17 -0.757289 -0.578580
# 2023-05-18 -0.701479 -0.532478
# 2023-05-19 -5.668251 -5.834950
#
# [12820 rows x 2 columns]

# %%
# train_df에 거래량 feature도 추가 
train_df = pd.merge(train_df, nasdaq_vol_df, left_index=True, right_index=True)
train_df
# Out:
#             return_b20  return_b40  return_b60  return_b80  return_b100  \
# Date
# 1971-02-05         NaN         NaN         NaN         NaN          NaN
# 1971-02-08         NaN         NaN         NaN         NaN          NaN
# 1971-02-09         NaN         NaN         NaN         NaN          NaN
# 1971-02-10         NaN         NaN         NaN         NaN          NaN
# 1971-02-11         NaN         NaN         NaN         NaN          NaN
# ...                ...         ...         ...         ...          ...
# 2023-05-15    0.000846    0.001531    0.000701    0.001631     0.001591
# 2023-05-16    0.000774    0.001390    0.000768    0.001281     0.001572
# 2023-05-17    0.001393    0.001315    0.001402    0.001191     0.001547
# 2023-05-18    0.002543    0.002093    0.001629    0.001411     0.001916
# 2023-05-19    0.002581    0.001888    0.001539    0.001457     0.001914
#
#             vol_z100  vol_z200
# Date
# 1971-02-05       NaN       NaN
# 1971-02-08       NaN       NaN
# 1971-02-09       NaN       NaN
# 1971-02-10       NaN       NaN
# 1971-02-11       NaN       NaN
# ...              ...       ...
# 2023-05-15 -1.541453 -1.326617
# 2023-05-16 -1.389622 -1.191260
# 2023-05-17 -0.757289 -0.578580
# 2023-05-18 -0.701479 -0.532478
# 2023-05-19 -5.668251 -5.834950
#
# [12820 rows x 7 columns]

# %% [markdown]
# ##### 20년 데이터 뽑기

# %%
train_20df = train_df[year:]
# nasdaq_df_y.drop(labels="price", axis=1, inplace=True)

train_20df
# Out:
#             return_b20  return_b40  return_b60  return_b80  return_b100  \
# Date
# 2003-05-19    0.002345    0.001217    0.001688    0.000907     0.000773
# 2003-05-20    0.001350    0.002121    0.002001    0.001316     0.000829
# 2003-05-21    0.000802    0.001716    0.001905    0.001463     0.000854
# 2003-05-22    0.001697    0.002075    0.002422    0.001452     0.001116
# 2003-05-23    0.002566    0.002175    0.002193    0.001326     0.001198
# ...                ...         ...         ...         ...          ...
# 2023-05-15    0.000846    0.001531    0.000701    0.001631     0.001591
# 2023-05-16    0.000774    0.001390    0.000768    0.001281     0.001572
# 2023-05-17    0.001393    0.001315    0.001402    0.001191     0.001547
# 2023-05-18    0.002543    0.002093    0.001629    0.001411     0.001916
# 2023-05-19    0.002581    0.001888    0.001539    0.001457     0.001914
#
#             vol_z100  vol_z200
# Date
# 2003-05-19  0.914290  0.627884
# 2003-05-20  0.992407  0.679856
# 2003-05-21  0.518252  0.264037
# 2003-05-22  1.363241  0.981462
# 2003-05-23 -0.152838 -0.259221
# ...              ...       ...
# 2023-05-15 -1.541453 -1.326617
# 2023-05-16 -1.389622 -1.191260
# 2023-05-17 -0.757289 -0.578580
# 2023-05-18 -0.701479 -0.532478
# 2023-05-19 -5.668251 -5.834950
#
# [5037 rows x 7 columns]

# %% [markdown]
# #### 유클리디안 거리

# %%
# 가장 마지막 행의 데이터 추출
# nasdaq_df.dropna().tail(20).index[19]
last_date = nasdaq_df.tail(1).index

last_date
# Out:
# DatetimeIndex(['2023-05-19'], dtype='datetime64[ns]', name='Date', freq=None)

# %%
nasdaq_df.loc[last_date]
# Out:
#                    price     Volume
# Date
# 2023-05-19  12711.992188  357870770

# %%
# random.randint(10,100)
start = 10
end = 300
n = 10
random.seed(10)
random_lst = random.choices(range(start, end), k=n)
random_lst
# Out:
# [175, 134, 177, 69, 245, 248, 199, 56, 160, 105]

# %%
eucli_sort(nasdaq_df,train_20df,30)

# %%
# 수익률 프린트
for idx in random_lst:
    date = eval(f"last_date{idx}")
    print(date)
    #print(date.date())
            
    # 실제 수익률 값 뽑아내기
    return_df = test_df[test_df.index.isin(eval(f"eucli_sort_num{idx}").index)]
    for future_d in future:
        print(f'return a{future_d}: ', format(return_df[f'return_a{future_d}'].mean(),'.4f'))
        print(f'std a{future_d}: ', format(return_df[f'return_a{future_d}'].std(),'.4f'))
        print(f'실제 {future_d}일 후 수익률: ', round(test_df[test_df.index == date][f'return_a{future_d}'][0],4))
    print()
# Out:
# 2022-11-18 00:00:00
# return a10:  -0.0051
# std a10:  0.0484
# 실제 10일 후 수익률:  0.0084
# return a20:  -0.0083
# std a20:  0.0674
# 실제 20일 후 수익률:  -0.0538
# return a30:  -0.0006
# std a30:  0.0726
# 실제 30일 후 수익률:  -0.0617
# return a40:  0.0040
# std a40:  0.0781
# 실제 40일 후 수익률:  -0.0264
#
# 2022-09-22 00:00:00
# return a10:  0.0072
# std a10:  0.0374
# 실제 10일 후 수익률:  0.0006
# return a20:  0.0011
# std a20:  0.0511
# 실제 20일 후 수익률:  -0.0408
# return a30:  0.0027
# std a30:  0.0566
# 실제 30일 후 수익률:  -0.0654
# return a40:  0.0210
# std a40:  0.0695
# 실제 40일 후 수익률:  0.0071
#
# 2022-11-22 00:00:00
# return a10:  0.0155
# std a10:  0.0325
# 실제 10일 후 수익률:  -0.0193
# return a20:  0.0137
# std a20:  0.0499
# 실제 20일 후 수익률:  -0.0416
# return a30:  0.0225
# std a30:  0.0548
# 실제 30일 후 수익률:  -0.0542
# return a40:  0.0277
# std a40:  0.0649
# 실제 40일 후 수익률:  0.017
#
# 2022-06-21 00:00:00
# return a10:  0.0048
# std a10:  0.0520
# 실제 10일 후 수익률:  0.0264
# return a20:  0.0158
# std a20:  0.0518
# 실제 20일 후 수익률:  0.0748
# return a30:  0.0338
# std a30:  0.0584
# 실제 30일 후 수익률:  0.1444
# return a40:  0.0463
# std a40:  0.0660
# 실제 40일 후 수익률:  0.1688
#
# 2023-03-03 00:00:00
# return a10:  -0.0016
# std a10:  0.0317
# 실제 10일 후 수익률:  -0.005
# return a20:  0.0013
# std a20:  0.0701
# 실제 20일 후 수익률:  0.0456
# return a30:  0.0112
# std a30:  0.0724
# 실제 30일 후 수익률:  0.0401
# return a40:  0.0186
# std a40:  0.0748
# 실제 40일 후 수익률:  0.0448
#
# 2023-03-08 00:00:00
# return a10:  -0.0004
# std a10:  0.0322
# 실제 10일 후 수익률:  0.0081
# return a20:  -0.0059
# std a20:  0.0695
# 실제 20일 후 수익률:  0.0364
# return a30:  -0.0006
# std a30:  0.0635
# 실제 30일 후 수익률:  0.0418
# return a40:  0.0118
# std a40:  0.0607
# 실제 40일 후 수익률:  0.0337
#
# 2022-12-23 00:00:00
# return a10:  0.0118
# std a10:  0.0371
# 실제 10일 후 수익률:  0.0233
# return a20:  0.0105
# std a20:  0.0547
# 실제 20일 후 수익률:  0.0777
# return a30:  0.0130
# std a30:  0.0697
# 실제 30일 후 수익률:  0.1346
# return a40:  0.0176
# std a40:  0.0708
# 실제 40일 후 수익률:  0.1041
#
# 2022-06-01 00:00:00
# return a10:  0.0038
# std a10:  0.0425
# 실제 10일 후 수익률:  -0.0746
# return a20:  0.0114
# std a20:  0.0617
# 실제 20일 후 수익률:  -0.0805
# return a30:  0.0205
# std a30:  0.0637
# 실제 30일 후 수익률:  -0.0452
# return a40:  0.0325
# std a40:  0.0692
# 실제 40일 후 수익률:  0.033
#
# 2022-10-28 00:00:00
# return a10:  0.0110
# std a10:  0.0350
# 실제 10일 후 수익률:  0.0199
# return a20:  0.0187
# std a20:  0.0567
# 실제 20일 후 수익률:  -0.0048
# return a30:  0.0262
# std a30:  0.0844
# 실제 30일 후 수익률:  0.0037
# return a40:  0.0194
# std a40:  0.1087
# 실제 40일 후 수익률:  -0.0675
#
# 2022-08-11 00:00:00
# return a10:  0.0038
# std a10:  0.0248
# 실제 10일 후 수익률:  -0.011
# return a20:  0.0015
# std a20:  0.0367
# 실제 20일 후 수익률:  -0.0522
# return a30:  -0.0005
# std a30:  0.0536
# 실제 30일 후 수익률:  -0.1496
# return a40:  0.0117
# std a40:  0.0585
# 실제 40일 후 수익률:  -0.1665

# %%
eucli_sort(nasdaq_df,train_20df,10)

# 수익률 프린트
for idx in random_lst:
    date = eval(f"last_date{idx}")
    print(date)
    #print(date.date())
            
    # 실제 수익률 값 뽑아내기
    return_df = test_df[test_df.index.isin(eval(f"eucli_sort_num{idx}").index)]
    for future_d in future:
        print(f'return a{future_d}: ', format(return_df[f'return_a{future_d}'].mean(),'.4f'))
        print(f'std a{future_d}: ', format(return_df[f'return_a{future_d}'].std(),'.4f'))
        print(f'실제 {future_d}일 후 수익률: ', round(test_df[test_df.index == date][f'return_a{future_d}'][0],4))
    print()
# Out:
# 2022-11-18 00:00:00
# return a10:  -0.0032
# std a10:  0.0499
# 실제 10일 후 수익률:  0.0084
# return a20:  -0.0072
# std a20:  0.0824
# 실제 20일 후 수익률:  -0.0538
# return a30:  0.0026
# std a30:  0.0900
# 실제 30일 후 수익률:  -0.0617
# return a40:  0.0042
# std a40:  0.1048
# 실제 40일 후 수익률:  -0.0264
#
# 2022-09-22 00:00:00
# return a10:  0.0049
# std a10:  0.0352
# 실제 10일 후 수익률:  0.0006
# return a20:  -0.0252
# std a20:  0.0451
# 실제 20일 후 수익률:  -0.0408
# return a30:  -0.0273
# std a30:  0.0445
# 실제 30일 후 수익률:  -0.0654
# return a40:  -0.0016
# std a40:  0.0564
# 실제 40일 후 수익률:  0.0071
#
# 2022-11-22 00:00:00
# return a10:  0.0078
# std a10:  0.0386
# 실제 10일 후 수익률:  -0.0193
# return a20:  0.0028
# std a20:  0.0632
# 실제 20일 후 수익률:  -0.0416
# return a30:  0.0092
# std a30:  0.0696
# 실제 30일 후 수익률:  -0.0542
# return a40:  0.0146
# std a40:  0.0808
# 실제 40일 후 수익률:  0.017
#
# 2022-06-21 00:00:00
# return a10:  -0.0063
# std a10:  0.0441
# 실제 10일 후 수익률:  0.0264
# return a20:  0.0172
# std a20:  0.0445
# 실제 20일 후 수익률:  0.0748
# return a30:  0.0354
# std a30:  0.0741
# 실제 30일 후 수익률:  0.1444
# return a40:  0.0400
# std a40:  0.0901
# 실제 40일 후 수익률:  0.1688
#
# 2023-03-03 00:00:00
# return a10:  -0.0028
# std a10:  0.0300
# 실제 10일 후 수익률:  -0.005
# return a20:  -0.0171
# std a20:  0.1024
# 실제 20일 후 수익률:  0.0456
# return a30:  0.0048
# std a30:  0.0852
# 실제 30일 후 수익률:  0.0401
# return a40:  0.0086
# std a40:  0.0663
# 실제 40일 후 수익률:  0.0448
#
# 2023-03-08 00:00:00
# return a10:  0.0020
# std a10:  0.0344
# 실제 10일 후 수익률:  0.0081
# return a20:  0.0036
# std a20:  0.0502
# 실제 20일 후 수익률:  0.0364
# return a30:  -0.0071
# std a30:  0.0694
# 실제 30일 후 수익률:  0.0418
# return a40:  0.0095
# std a40:  0.0638
# 실제 40일 후 수익률:  0.0337
#
# 2022-12-23 00:00:00
# return a10:  0.0259
# std a10:  0.0186
# 실제 10일 후 수익률:  0.0233
# return a20:  0.0200
# std a20:  0.0415
# 실제 20일 후 수익률:  0.0777
# return a30:  0.0348
# std a30:  0.0637
# 실제 30일 후 수익률:  0.1346
# return a40:  0.0325
# std a40:  0.0633
# 실제 40일 후 수익률:  0.1041
#
# 2022-06-01 00:00:00
# return a10:  0.0079
# std a10:  0.0446
# 실제 10일 후 수익률:  -0.0746
# return a20:  0.0183
# std a20:  0.0759
# 실제 20일 후 수익률:  -0.0805
# return a30:  0.0219
# std a30:  0.0731
# 실제 30일 후 수익률:  -0.0452
# return a40:  0.0344
# std a40:  0.0587
# 실제 40일 후 수익률:  0.033
#
# 2022-10-28 00:00:00
# return a10:  0.0167
# std a10:  0.0397
# 실제 10일 후 수익률:  0.0199
# return a20:  0.0334
# std a20:  0.0672
# 실제 20일 후 수익률:  -0.0048
# return a30:  0.0347
# std a30:  0.1138
# 실제 30일 후 수익률:  0.0037
# return a40:  0.0211
# std a40:  0.1393
# 실제 40일 후 수익률:  -0.0675
#
# 2022-08-11 00:00:00
# return a10:  0.0147
# std a10:  0.0148
# 실제 10일 후 수익률:  -0.011
# return a20:  0.0098
# std a20:  0.0403
# 실제 20일 후 수익률:  -0.0522
# return a30:  -0.0085
# std a30:  0.0689
# 실제 30일 후 수익률:  -0.1496
# return a40:  0.0055
# std a40:  0.0742
# 실제 40일 후 수익률:  -0.1665

# %%
eucli_sort(nasdaq_df,train_20df,20)

# 수익률 프린트
for idx in random_lst:
    date = eval(f"last_date{idx}")
    print(date)
    #print(date.date())
            
    # 실제 수익률 값 뽑아내기
    return_df = test_df[test_df.index.isin(eval(f"eucli_sort_num{idx}").index)]
    for future_d in future:
        print(f'return a{future_d}: ', format(return_df[f'return_a{future_d}'].mean(),'.4f'))
        print(f'std a{future_d}: ', format(return_df[f'return_a{future_d}'].std(),'.4f'))
        print(f'실제 {future_d}일 후 수익률: ', round(test_df[test_df.index == date][f'return_a{future_d}'][0],4))
    print()
# Out:
# 2022-11-18 00:00:00
# return a10:  -0.0071
# std a10:  0.0507
# 실제 10일 후 수익률:  0.0084
# return a20:  -0.0163
# std a20:  0.0770
# 실제 20일 후 수익률:  -0.0538
# return a30:  -0.0041
# std a30:  0.0787
# 실제 30일 후 수익률:  -0.0617
# return a40:  -0.0060
# std a40:  0.0884
# 실제 40일 후 수익률:  -0.0264
#
# 2022-09-22 00:00:00
# return a10:  0.0034
# std a10:  0.0410
# 실제 10일 후 수익률:  0.0006
# return a20:  -0.0005
# std a20:  0.0531
# 실제 20일 후 수익률:  -0.0408
# return a30:  -0.0026
# std a30:  0.0626
# 실제 30일 후 수익률:  -0.0654
# return a40:  0.0138
# std a40:  0.0748
# 실제 40일 후 수익률:  0.0071
#
# 2022-11-22 00:00:00
# return a10:  0.0158
# std a10:  0.0327
# 실제 10일 후 수익률:  -0.0193
# return a20:  0.0145
# std a20:  0.0506
# 실제 20일 후 수익률:  -0.0416
# return a30:  0.0182
# std a30:  0.0573
# 실제 30일 후 수익률:  -0.0542
# return a40:  0.0297
# std a40:  0.0714
# 실제 40일 후 수익률:  0.017
#
# 2022-06-21 00:00:00
# return a10:  -0.0002
# std a10:  0.0569
# 실제 10일 후 수익률:  0.0264
# return a20:  0.0161
# std a20:  0.0511
# 실제 20일 후 수익률:  0.0748
# return a30:  0.0317
# std a30:  0.0569
# 실제 30일 후 수익률:  0.1444
# return a40:  0.0428
# std a40:  0.0668
# 실제 40일 후 수익률:  0.1688
#
# 2023-03-03 00:00:00
# return a10:  -0.0025
# std a10:  0.0339
# 실제 10일 후 수익률:  -0.005
# return a20:  0.0013
# std a20:  0.0853
# 실제 20일 후 수익률:  0.0456
# return a30:  0.0115
# std a30:  0.0852
# 실제 30일 후 수익률:  0.0401
# return a40:  0.0183
# std a40:  0.0843
# 실제 40일 후 수익률:  0.0448
#
# 2023-03-08 00:00:00
# return a10:  -0.0019
# std a10:  0.0350
# 실제 10일 후 수익률:  0.0081
# return a20:  -0.0129
# std a20:  0.0791
# 실제 20일 후 수익률:  0.0364
# return a30:  -0.0139
# std a30:  0.0710
# 실제 30일 후 수익률:  0.0418
# return a40:  0.0054
# std a40:  0.0627
# 실제 40일 후 수익률:  0.0337
#
# 2022-12-23 00:00:00
# return a10:  0.0147
# std a10:  0.0380
# 실제 10일 후 수익률:  0.0233
# return a20:  0.0123
# std a20:  0.0554
# 실제 20일 후 수익률:  0.0777
# return a30:  0.0168
# std a30:  0.0751
# 실제 30일 후 수익률:  0.1346
# return a40:  0.0155
# std a40:  0.0754
# 실제 40일 후 수익률:  0.1041
#
# 2022-06-01 00:00:00
# return a10:  0.0036
# std a10:  0.0455
# 실제 10일 후 수익률:  -0.0746
# return a20:  0.0089
# std a20:  0.0655
# 실제 20일 후 수익률:  -0.0805
# return a30:  0.0200
# std a30:  0.0637
# 실제 30일 후 수익률:  -0.0452
# return a40:  0.0282
# std a40:  0.0687
# 실제 40일 후 수익률:  0.033
#
# 2022-10-28 00:00:00
# return a10:  0.0137
# std a10:  0.0389
# 실제 10일 후 수익률:  0.0199
# return a20:  0.0239
# std a20:  0.0647
# 실제 20일 후 수익률:  -0.0048
# return a30:  0.0296
# std a30:  0.0949
# 실제 30일 후 수익률:  0.0037
# return a40:  0.0239
# std a40:  0.1280
# 실제 40일 후 수익률:  -0.0675
#
# 2022-08-11 00:00:00
# return a10:  0.0034
# std a10:  0.0245
# 실제 10일 후 수익률:  -0.011
# return a20:  -0.0010
# std a20:  0.0414
# 실제 20일 후 수익률:  -0.0522
# return a30:  -0.0147
# std a30:  0.0573
# 실제 30일 후 수익률:  -0.1496
# return a40:  -0.0048
# std a40:  0.0594
# 실제 40일 후 수익률:  -0.1665

# %%
eucli_sort(nasdaq_df,train_20df,50)

# 수익률 프린트
for idx in random_lst:
    date = eval(f"last_date{idx}")
    print(date)
    #print(date.date())
            
    # 실제 수익률 값 뽑아내기
    return_df = test_df[test_df.index.isin(eval(f"eucli_sort_num{idx}").index)]
    for future_d in future:
        print(f'return a{future_d}: ', format(return_df[f'return_a{future_d}'].mean(),'.4f'))
        print(f'std a{future_d}: ', format(return_df[f'return_a{future_d}'].std(),'.4f'))
        print(f'실제 {future_d}일 후 수익률: ', round(test_df[test_df.index == date][f'return_a{future_d}'][0],4))
    print()
# Out:
# 2022-11-18 00:00:00
# return a10:  -0.0012
# std a10:  0.0433
# 실제 10일 후 수익률:  0.0084
# return a20:  0.0002
# std a20:  0.0622
# 실제 20일 후 수익률:  -0.0538
# return a30:  0.0076
# std a30:  0.0743
# 실제 30일 후 수익률:  -0.0617
# return a40:  0.0088
# std a40:  0.0859
# 실제 40일 후 수익률:  -0.0264
#
# 2022-09-22 00:00:00
# return a10:  0.0102
# std a10:  0.0377
# 실제 10일 후 수익률:  0.0006
# return a20:  0.0074
# std a20:  0.0471
# 실제 20일 후 수익률:  -0.0408
# return a30:  0.0088
# std a30:  0.0541
# 실제 30일 후 수익률:  -0.0654
# return a40:  0.0263
# std a40:  0.0712
# 실제 40일 후 수익률:  0.0071
#
# 2022-11-22 00:00:00
# return a10:  0.0016
# std a10:  0.0434
# 실제 10일 후 수익률:  -0.0193
# return a20:  0.0022
# std a20:  0.0553
# 실제 20일 후 수익률:  -0.0416
# return a30:  0.0104
# std a30:  0.0619
# 실제 30일 후 수익률:  -0.0542
# return a40:  0.0187
# std a40:  0.0654
# 실제 40일 후 수익률:  0.017
#
# 2022-06-21 00:00:00
# return a10:  0.0019
# std a10:  0.0470
# 실제 10일 후 수익률:  0.0264
# return a20:  0.0098
# std a20:  0.0514
# 실제 20일 후 수익률:  0.0748
# return a30:  0.0244
# std a30:  0.0627
# 실제 30일 후 수익률:  0.1444
# return a40:  0.0299
# std a40:  0.0620
# 실제 40일 후 수익률:  0.1688
#
# 2023-03-03 00:00:00
# return a10:  0.0004
# std a10:  0.0284
# 실제 10일 후 수익률:  -0.005
# return a20:  0.0053
# std a20:  0.0583
# 실제 20일 후 수익률:  0.0456
# return a30:  0.0129
# std a30:  0.0637
# 실제 30일 후 수익률:  0.0401
# return a40:  0.0210
# std a40:  0.0648
# 실제 40일 후 수익률:  0.0448
#
# 2023-03-08 00:00:00
# return a10:  0.0015
# std a10:  0.0302
# 실제 10일 후 수익률:  0.0081
# return a20:  -0.0015
# std a20:  0.0578
# 실제 20일 후 수익률:  0.0364
# return a30:  0.0064
# std a30:  0.0566
# 실제 30일 후 수익률:  0.0418
# return a40:  0.0152
# std a40:  0.0546
# 실제 40일 후 수익률:  0.0337
#
# 2022-12-23 00:00:00
# return a10:  0.0085
# std a10:  0.0374
# 실제 10일 후 수익률:  0.0233
# return a20:  0.0076
# std a20:  0.0578
# 실제 20일 후 수익률:  0.0777
# return a30:  -0.0005
# std a30:  0.0881
# 실제 30일 후 수익률:  0.1346
# return a40:  0.0071
# std a40:  0.0979
# 실제 40일 후 수익률:  0.1041
#
# 2022-06-01 00:00:00
# return a10:  0.0080
# std a10:  0.0364
# 실제 10일 후 수익률:  -0.0746
# return a20:  0.0213
# std a20:  0.0522
# 실제 20일 후 수익률:  -0.0805
# return a30:  0.0304
# std a30:  0.0563
# 실제 30일 후 수익률:  -0.0452
# return a40:  0.0350
# std a40:  0.0611
# 실제 40일 후 수익률:  0.033
#
# 2022-10-28 00:00:00
# return a10:  0.0174
# std a10:  0.0477
# 실제 10일 후 수익률:  0.0199
# return a20:  0.0231
# std a20:  0.0615
# 실제 20일 후 수익률:  -0.0048
# return a30:  0.0284
# std a30:  0.0828
# 실제 30일 후 수익률:  0.0037
# return a40:  0.0279
# std a40:  0.1027
# 실제 40일 후 수익률:  -0.0675
#
# 2022-08-11 00:00:00
# return a10:  0.0024
# std a10:  0.0251
# 실제 10일 후 수익률:  -0.011
# return a20:  0.0053
# std a20:  0.0374
# 실제 20일 후 수익률:  -0.0522
# return a30:  0.0022
# std a30:  0.0541
# 실제 30일 후 수익률:  -0.1496
# return a40:  0.0112
# std a40:  0.0627
# 실제 40일 후 수익률:  -0.1665

# %%
# sort_num = 30

# for i in random_lst:
#     # 마지막 행 날짜 추출
#     exec(f"last_date{i} = str(nasdaq_df.dropna().tail(end).index[{i}])")
#     # 마지막 행 데이터 추출
#     exec(f"last_row{i} = train_20df.loc[last_date{i}]")
#     # 가장 마지막 행과 다른 행들 간의 유클리디안 디스턴스 계산
#     exec(f"euclidean_distances{i} = train_20df.apply(lambda row: distance.euclidean(row, last_row{i}), axis=1)")
#     exec(f"eucli{i} = euclidean_distances{i}")
#     # sorting 하기
#     exec(f"eucli_sort{i} = eucli{i}.sort_values()")
#     # sort_num 만큼 sorting 하기
#     exec(f"eucli_sort_num{i} = eucli_sort{i}.head(sort_num)")
    
# for idx in random_lst:
#     date = eval(f"last_date{idx}")
#     print(date)
# #     print(date.date())
#     for future_d in future:
#         print(f'return a{future_d}: ', format(test_df[f'return_a{future_d}'].mean(),'.4f'))
#         print(f'std a{future_d}: ', format(test_df[f'return_a{future_d}'].std(),'.4f'))
#         print(f'실제 {future_d}일 후 수익률: ', round(test_df[test_df.index == date][f'return_a{future_d}'][0],4))
#     print()

# %%
nasdaq_ex = nasdaq[nasdaq.index.isin(eucli_sort_num.index)]
nasdaq_ex2 = nasdaq[nasdaq.index.isin(eucli_sort_num2.index)]
nasdaq_ex3 = nasdaq[nasdaq.index.isin(eucli_sort_num3.index)]
nasdaq_ex4 = nasdaq[nasdaq.index.isin(eucli_sort_num4.index)]
nasdaq_ex5 = nasdaq[nasdaq.index.isin(eucli_sort_num5.index)]

nasdaq_ex2
# Out:
#                    price      Volume  return_a20  return_a10  return_a30  \
# Date
# 2022-10-27  10792.669922  4773520000    0.040184    0.029787    0.019638
# 2022-10-28  11102.450195  4731940000   -0.004769    0.019895    0.003719
# 2022-10-31  10988.150391  4753740000   -0.000398    0.018936    0.024450
# 2022-11-01  10890.849609  4677520000    0.052994    0.042932    0.025713
# 2022-11-02  10524.799805  5436420000    0.090990    0.062601    0.027148
# 2022-11-03  10342.940430  5102190000    0.108147    0.077543    0.035045
# 2022-11-04  10475.250000  5453750000    0.073000    0.064038    0.006757
# 2022-11-07  10564.519531  4456690000    0.042630    0.043541   -0.001648
# 2022-11-08  10616.200195  5134500000    0.032248    0.052581    0.008776
# 2022-11-09  10353.169922  4977460000    0.070397    0.090035    0.011876
# 2022-11-10  11114.150391  6433000000   -0.009855    0.010096   -0.055451
# 2022-11-22  11174.410156  4186360000   -0.041617   -0.019317   -0.054152
# 2022-11-23  11285.320312  4431530000   -0.071704   -0.018016   -0.057568
# 2022-11-25  11226.360352  2184080000   -0.064892   -0.019752   -0.043089
# 2022-11-28  11049.500000  4271360000   -0.063014    0.008529   -0.010664
# 2022-11-29  10983.780273  4592830000   -0.070148    0.024857    0.001577
# 2022-11-30  11468.000000  6653460000   -0.086319   -0.025908   -0.033907
# 2022-12-01  11482.450195  5158120000   -0.088480   -0.058517   -0.033733
# 2022-12-02  11461.500000  4523010000   -0.093750   -0.065968   -0.044016
# 2022-12-05  11239.940430  4510030000   -0.069500   -0.061736   -0.034490
# 2022-12-06  11014.889648  4713330000   -0.064426   -0.042468    0.011397
# 2022-12-07  10958.549805  4343860000   -0.035521   -0.022738    0.037036
# 2022-12-28  10213.290039  3842970000    0.137901    0.077136    0.147340
# 2022-12-29  10478.089844  4154100000    0.087394    0.057364    0.134920
# 2022-12-30  10466.480469  3959030000    0.106824    0.060061    0.142710
# 2023-01-03  10386.980469  4780650000    0.137609    0.054879    0.162088
# 2023-01-04  10458.759766  5085380000    0.166565    0.037625    0.133579
# 2023-01-05  10305.240234  4764270000    0.165131    0.081045    0.143813
# 2023-01-06  10569.290039  5199780000    0.124716    0.075229    0.087329
# 2023-01-09  10635.650391  5132190000    0.138980    0.065687    0.081934
#
#             return_a40
# Date
# 2022-10-27   -0.027316
# 2022-10-28   -0.067482
# 2022-10-31   -0.070518
# 2022-11-01   -0.037900
# 2022-11-02   -0.005541
# 2022-11-03    0.004258
# 2022-11-04   -0.001574
# 2022-11-07   -0.024542
# 2022-11-08   -0.004419
# 2022-11-09    0.027284
# 2022-11-10   -0.033428
# 2022-11-22    0.017003
# 2022-11-23    0.004337
# 2022-11-25    0.007750
# 2022-11-28    0.041894
# 2022-11-29    0.058079
# 2022-11-30   -0.006469
# 2022-12-01    0.008892
# 2022-12-02    0.030958
# 2022-12-05    0.085488
# 2022-12-06    0.090065
# 2022-12-07    0.084765
# 2022-12-28    0.122751
# 2022-12-29    0.093285
# 2022-12-30    0.087231
# 2023-01-03    0.103591
# 2023-01-04    0.117629
# 2023-01-05    0.132991
# 2023-01-06    0.090928
# 2023-01-09    0.088415

# %%
# type(nasdaq[nasdaq.index == last_date].return_a20)
# round(nasdaq[nasdaq.index == last_date].return_a20[0],4)

# %% [markdown]
# 230515 랩미팅
# 1. 의미있게 나온 날짜가 몇개인지 & 언젠지: 의미있는 기준: 방향성 & 표준편차 참고
# 2. sort_num을 30개로 했는데 10개 등등 여러 파라미터 시도 해보기.(10,20,30)
# 3. 점끼리 말고 기간 비교,,,
# 4. 가장 가깝다고 하는 애들이랑 그래프 비교해보기(경로 비교)
# 5. 할 수 있으면 무엇 때문에 표준편차가 커지는지 찾아보기
# 6. 초기에 한 모델로 가는게 맞나나ㅏㅏㅏ 여쭤보기
# 7. 거래량 이동평균 말고 z-score로 바꾸기
# 8. daily 수익률 말고 3일 이동평균 수익률이 좋을 수도 있다.

# %%
nasdaq[nasdaq.index == last_date]["return_a20"]
# Out:
# Date
# 2023-03-21    0.025052
# Name: return_a20, dtype: float64

# %% [markdown]
# -코멘트 달기
# -df인지 시리즈인지 등 변수명에 표시해주기
# def test_today # 이런식으로 함수를 여러개 만들어 놓기 -> 스크립트로 하지 x.
# -데이터 불러오는 함수, 엔지니어링 함수(20,40,60 etc.), test_today, 최종 백테스트 등의 함수.
# -과거랑 비교할 때 어느 것을 점수줄지 생각해보기. 같은 방향이면 적게 차이 주거나 etc.
# -L1, L2(유클리디안) 같은 것도 다 고려해보면 좋다.
# -백테스트 과거 전체 해보기.
# -표준편차
# -할 것: 10,20,30,40,50일 상위 sorting 해보기
# -4월 17일만 하지 말고, 이 외에 그냥 10개 선정해서 해보기.

# %%
# plt.hist(weight)

# plt.show()
